# %% [markdown]
# > Untitled2
# > April 18, 2023
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><p>[ ]: 1.</p>
# <blockquote>
# <p>Abstraction <strong>is</strong> a fundamental concept
# <strong>in</strong> object-oriented programming (OOP) that␣features of
# an object <strong>while</strong> hiding the implementation details.
# Abstraction <strong>is</strong>␣↪allows you to focus on the
# essential<br />
# <strong>and</strong> interfaces, which provide a way to define common
# behaviors <strong>and</strong> properties␣↪achieved through the use of
# abstract classes<br />
# ↪that can be shared by multiple objects.</p>
# <p>An abstract <strong>class is</strong> a <strong>class that</strong>
# cannot be instantiated, but provides a␣It contains abstract methods,
# which are methods that have no implementation
# <strong>and</strong>␣↪blueprint <strong>for</strong> other classes to
# follow.</p>
# <p>that inherit <strong>from the</strong> abstract class. Abstract
# classes are typically used to␣↪must be overridden by the
# subclasses<br />
# a group of related classes must implement, but leave the details of
# their␣↪define a set of methods <strong>and</strong> properties
# that<br />
# ↪implementation up to the individual classes.</p>
# <p>Here's a simple example of an abstract class in Python that defines
# the basic␣ ↪properties and methods of a shape:<br />
# <strong>from abc import</strong> ABC, abstractmethod</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>class Shape</strong>(ABC):<br />
# @abstractmethod<br />
# <strong>def</strong> area(self):<br />
# <strong>pass</strong></p>
# <p>@abstractmethod<br />
# <strong>def</strong> perimeter(self):<br />
# <strong>pass</strong><br />
# In this example, the Shape <strong>class is</strong> an abstract
# <strong>class that</strong> defines two abstract␣</p>
# <p>Any <strong>class that</strong> inherits <strong>from Shape</strong>
# must implement these methods, but the Shape␣↪methods, area
# <strong>and</strong> perimeter.</p>
# <p><strong>for</strong> them.↪<strong>class itself</strong> provides no
# implementation</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# 1
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>Here's an example of a class that inherits from the Shape class and
# implements␣ ↪its abstract methods:<br />
# <strong>class Rectangle</strong>(Shape):<br />
# <strong>def</strong> _init_(self, width, height):<br />
# self.width = width<br />
# self.height = height</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>def</strong> area(self):</p>
# <p><strong>return</strong> self.width * self.height</p>
# <p><strong>def</strong> perimeter(self):</p>
# <p><strong>return</strong> 2 * (self.width + self.height)</p>
# <p>In this example, the Rectangle <strong>class inherits from
# the</strong> Shape <strong>class and</strong> provides␣</p>
# <p>perimeter methods. By doing this, the Rectangle <strong>class
# can</strong> be treated <strong>as</strong> a Shape␣↪implementations
# <strong>for</strong> the area <strong>and</strong></p>
# <p>can be called without needing to know the implementation details of
# the␣↪object, <strong>and</strong> its area <strong>and</strong>
# perimeter methods</p>
# <p><strong>in</strong> OOP↪Rectangle class. This <strong>is</strong> an
# example of abstraction</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><p>[ ]: 2.</p>
# <p>Abstraction <strong>and</strong> encapsulation are two important
# concepts <strong>in</strong> object-oriented␣</p>
# <blockquote>
# <p>Both concepts focus on hiding complexity <strong>and</strong>
# implementation details, but they␣↪programming that are often used
# together.</p>
# <p>↪have different objectives <strong>and</strong> approaches.</p>
# </blockquote>
# <p>Abstraction <strong>is</strong> the process of hiding unnecessary
# implementation details <strong>and</strong>␣</p>
# <blockquote>
# <p>user. Abstraction allows us to focus on the essential features of an
# object,␣↪showing only the necessary information to the</p>
# <p>Abstraction <strong>is</strong> achieved through abstract classes
# <strong>and</strong> interfaces.↪without worrying about how they are
# implemented.</p>
# <p>Encapsulation <strong>is</strong> the process of hiding the
# implementation details of an object␣</p>
# <p>to it only through a public interface. Encapsulation allows us to
# protect the␣↪<strong>from the</strong> outside world
# <strong>and</strong> providing access</p>
# </blockquote>
# <p>access <strong>and</strong> modification. Encapsulation
# <strong>is</strong> achieved through access modifiers␣↪data
# <strong>and</strong> behavior of an object <strong>from
# unauthorized</strong></p>
# <blockquote>
# <p>↪like public, private, <strong>and</strong> protected.</p>
# <p>Here's an example in Python to illustrate the difference between
# abstraction␣</p>
# <p>↪and encapsulation:</p>
# <p><strong>from abc import</strong> ABC, abstractmethod</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > **class Shape**(ABC):
#
# 2
#
# > **def** \_init\_(self, x, y):
# > self.x = x
# > self.y = y
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>@abstractmethod<br />
# <strong>def</strong> area(self):<br />
# <strong>pass</strong></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>@abstractmethod<br />
# <strong>def</strong> perimeter(self):<br />
# <strong>pass</strong></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>class Circle</strong>(Shape):<br />
# <strong>def</strong> _init_(self, x, y, r):<br />
# super()._init_(x, y)<br />
# self.r = r</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > **def** area(self):
# > **return** 3.14 \* self.r \* self.r
# >
# > **def** perimeter(self):
# > **return** 2 \* 3.14 \* self.r
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>class Rectangle</strong>(Shape):<br />
# <strong>def</strong> _init_(self, x, y, l, w):<br />
# super()._init_(x, y)<br />
# self.l = l<br />
# self.w = w</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > **def** area(self):
# > **return** self.l \* self.w
# >
# > **def** perimeter(self):
# > **return** 2 \* (self.l + self.w)
# >
# > circle = Circle(0, 0, 5)
# > rectangle = Rectangle(0, 0, 10, 5)
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><em># Accessing public properties of the objects</em><br />
# print("Circle area:", circle.area())<br />
# print("Rectangle perimeter:", rectangle.perimeter())</p>
# <p><em># Trying to access private properties of the objects</em><br />
# print("Circle radius:", circle.r) <em># AttributeError: 'Circle' object
# has no</em>␣</p>
# <p>print("Rectangle length:", rectangle.l) <em># AttributeError:
# 'Rectangle' object</em>␣↪<em>attribute 'r'</em><br />
# ↪<em>has no attribute 'l'</em></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# 3
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><p>In this example, the Shape <strong>class is</strong> an abstract
# <strong>class that</strong> defines two abstract␣</p>
# <blockquote>
# <p>The Circle <strong>and</strong> Rectangle classes are derived classes
# that inherit <strong>from the</strong>␣↪methods area
# <strong>and</strong> perimeter.</p>
# <p>↪Shape <strong>class and</strong> implement its abstract methods.</p>
# <p>The x <strong>and</strong> y properties of the Shape <strong>class
# are</strong> encapsulated because they are␣</p>
# <p>accessible <strong>from outside</strong> the class. The r
# <strong>and</strong> l properties of the Circle
# <strong>and</strong>␣↪initialized <strong>in</strong> the constructor
# <strong>and not</strong> directly</p>
# </blockquote>
# <p>they are defined <strong>as</strong> instance variables <strong>and
# not</strong> directly accessible <strong>from
# outside</strong>␣↪Rectangle classes are also encapsulated because</p>
# <blockquote>
# <p>↪the classes.</p>
# <p>The area <strong>and</strong> perimeter methods of the Circle
# <strong>and</strong> Rectangle classes are␣</p>
# <p><strong>class and</strong> implemented differently
# <strong>in</strong> the derived classes. The user does
# <strong>not</strong>␣↪abstracted because they are defined
# <strong>in</strong> the Shape</p>
# <p>are implemented, <strong>as</strong> long <strong>as</strong> they
# can access them through the public interface␣↪need to know how the area
# <strong>and</strong> perimeter methods</p>
# <p>↪of the Circle <strong>and</strong> Rectangle objects.</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>S</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><p>[ ]: 3.</p>
# <blockquote>
# <p>In Python, the abc module stands <strong>for</strong> "Abstract Base
# Classes". It provides a way␣</p>
# <p>classes that cannot be instantiated directly but can only be
# subclassed.␣↪to define abstract classes, which are</p>
# <p>properties that a subclass must implement <strong>in</strong> order
# to be considered a concrete␣↪Abstract classes define a set of methods
# <strong>or</strong></p>
# <p>↪(non-abstract) class.</p>
# <p>The abc module <strong>is</strong> used <strong>in</strong> Python to
# enforce a certain level of structure <strong>and</strong>␣</p>
# <p><strong>and</strong> polymorphism. By defining abstract classes
# <strong>and</strong> methods, you can ensure that␣↪consistency
# <strong>in</strong> code that involves inheritance</p>
# <p>all subclasses implement the necessary methods <strong>and</strong>
# properties.↪your code follows a certain pattern <strong>and</strong>
# that</p>
# <p>For example, imagine that you are writing a program that involves
# various␣</p>
# <p><strong>and</strong> triangles. Each shape has certain common
# attributes <strong>and</strong> methods, such <strong>as</strong>
# a␣↪geometric shapes, such <strong>as</strong> circles, squares,</p>
# <p>By defining an abstract <strong>class Shape</strong> that includes
# these methods, you can ensure␣↪area() method <strong>and</strong> a
# perimeter() method.</p>
# <p>these methods <strong>and</strong> that your program can work
# <strong>with</strong> any shape that inherits
# <strong>from</strong>␣↪that all subclasses of Shape implement</p>
# <p>↪<strong>Shape.</strong></p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# 4
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>Here <strong>is</strong> an example of how to define an abstract
# <strong>class using</strong> the abc module <strong>in</strong>␣
# ↪Python:</p>
# <p><strong>import abc</strong></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>class Shape</strong>(metaclass=abc.ABCMeta):<br />
# @abc.abstractmethod<br />
# <strong>def</strong> area(self):<br />
# <strong>pass</strong></p>
# <p>@abc.abstractmethod<br />
# <strong>def</strong> perimeter(self):<br />
# <strong>pass</strong><br />
# In this example, the Shape <strong>class is</strong> defined
# <strong>as</strong> an abstract <strong>class by</strong> including␣</p>
# <p><strong>class definition</strong>. The @abc.abstractmethod decorator
# <strong>is</strong> used to define two␣↪the metaclass=abc.ABCMeta
# argument <strong>in</strong> the</p>
# <p>that must be implemented by any concrete subclass of Shape.↪abstract
# methods, area() <strong>and</strong> perimeter(),</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>Using the abc module <strong>in</strong> Python can help make your
# code more modular <strong>and</strong>␣ ↪maintainable by enforcing a
# certain level of</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><p>[ ]: 4.</p>
# <blockquote>
# <p>Data abstraction <strong>is</strong> the process of hiding
# implementation details <strong>and</strong> showing␣</p>
# <p>the user. In Python, we can achieve data abstraction using classes
# <strong>and</strong> objects.↪only the necessary information to</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>Here's an example of how to achieve data abstraction in Python:</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>class BankAccount</strong>:<br />
# <strong>def</strong> _init_(self):<br />
# self.balance = 0</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>def</strong> deposit(self, amount):<br />
# self.balance += amount<br />
# print("Deposit Successful. Your new balance is:", self.balance)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>def</strong> withdraw(self, amount):<br />
# <strong>if</strong> self.balance &gt;= amount:<br />
# self.balance -= amount<br />
# print("Withdrawal Successful. Your new balance is:", self.balance)
# <strong>else</strong>:<br />
# print("Insufficient Balance")</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>def</strong> get_balance(self):<br />
# <strong>return</strong> self.balance</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# 5
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>account = BankAccount()</p>
# <p>account.deposit(1000)</p>
# <p>account.withdraw(500)</p>
# <p>balance = account.get_balance()</p>
# <p>print("Your current balance is:", balance)</p>
# <p>In this example, we have defined a BankAccount <strong>class
# that</strong> has three methods:␣</p>
# </blockquote>
# <p>These methods abstract away the implementation details of the
# BankAccount <strong>class</strong>␣↪deposit, withdraw,
# <strong>and</strong> get_balance.</p>
# <blockquote>
# <p>to the user.↪<strong>and</strong> only expose the necessary
# information</p>
# <p>The user can create an object of the BankAccount <strong>class
# and</strong> call its methods to␣</p>
# <p>The user doesn't need to know how these methods are implemented or
# how the␣↪deposit, withdraw <strong>and</strong> get the current
# balance.</p>
# <p>class. This <strong>is</strong> an example of data abstraction
# <strong>in</strong> Python.↪balance attribute is stored in the
# BankAccount</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > 5\. No, we cannot create an instance of an abstract class in Python.
# > An abstract class is a class that cannot be instantiated, meaning we
# > cannot create objects from it directly. Abstract classes in Python are
# > created using the abc (Abstract Base Class) module.
#
# To create an abstract class in Python, we need to use the ABC (Abstract
# Base Class) class from the abc module and define abstract methods using
# the @abstractmethod decorator. An abstract method is a method that is
# declared but does not contain any implementation. Abstract classes are
# meant to be used as base classes, and their abstract methods need to be
# implemented in the derived classes.
#
# Here’s an example of an abstract class in Python:
#
# from abc import ABC, abstractmethod
#
# class Shape(ABC): @abstractmethod def area(self): pass
#
# @abstractmethod
# def perimeter(self):
# pass
#
# In this example, the Shape class is an abstract class with two abstract
# methods area and perimeter. These methods do not contain any
# implementation, and we must implement them in the derived classes that
# inherit from the Shape class.
#
# If we try to create an instance of the Shape class, we will get a
# TypeError:
#
# shape = Shape()
# \# TypeError: Can’t instantiate abstract class Shape with abstract
# methods area, perimeter This error occurs because we cannot create an
# instance of an abstract class in Python. Instead, we must create a
# derived class that inherits from the abstract class and implement its
# abstract methods. Only then we can create an object of the derived
# class.
#
# 6
